# %%
# !pip3 install face-recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 100.1 MB 26 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=3e7d8170ee1c620144810ae2bfd84f312f9f877293e224605adacdbfe3007f7c
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
import face_recognition

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# load_image_file
# face_locations
# face_landmarks

# %%
known_image = face_recognition.load_image_file("/content/drive/MyDrive/Photos/Olmosbek.jpg","/content/drive/MyDrive/Photos/Ilhomjon.jpg","/content/drive/MyDrive/Photos/Azamat.jpg","/content/drive/MyDrive/Photos/Urazali.jpg")
unknown_image = face_recognition.load_image_file("/content/drive/MyDrive/Photos/Urazali_test.jpg")

known_encoding = face_recognition.face_encodings(known_image)[0]
unknown_encoding = face_recognition.face_encodings(unknown_image)[0]

result = face_recognition.compare_faces([known_encoding],unknown_encoding)

# %%
result
# Out:
# [True]

# %%
face_distances = face_recognition.face_distance([known_encoding],unknown_encoding)
for i , face_distance in enumerate(face_distances):
  print("Sinov rasmi ma'lum rasmdan{:.2} masofaga ega #{}".format(face_distance,i))
  # print("- Oddiy kesish 0,6 bo'lsa, sinov tasviri ma'lum tasvirga mos keladimi? {}")format()
# Out:
# Sinov rasmi ma'lum rasmdan0.3 masofaga ega #0
